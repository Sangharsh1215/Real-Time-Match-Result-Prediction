# %%
import papermill as pm

notebook_input_path = r"C:\Users\Sangharsh\Desktop\git\Real-Time-Match-Result-Prediction\Prem_Current_Table.ipynb"
notebook_output_path = r"C:\Users\Sangharsh\Desktop\git\Real-Time-Match-Result-Prediction\output.ipynb"

pm.execute_notebook(notebook_input_path, notebook_output_path)
# Out:
# Executing:   0%|          | 0/6 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:19.622378',
#      'end_time': '2024-09-25T09:38:20.314052',
#      'duration': 0.691674,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:19.624973Z',
#      'iopub.execute_input': '2024-09-25T09:38:19.624973Z',
#      'iopub.status.idle': '2024-09-25T09:38:20.313045Z',
#      'shell.execute_reply': '2024-09-25T09:38:20.313045Z'}},
#    'outputs': [],
#    'source': 'import pandas as pd',
#    'id': '49216a77'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:20.317070',
#      'end_time': '2024-09-25T09:38:21.898605',
#      'duration': 1.581535,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:20.319707Z',
#      'iopub.execute_input': '2024-09-25T09:38:20.319707Z',
#      'iopub.status.idle': '2024-09-25T09:38:21.897257Z',
#      'shell.execute_reply': '2024-09-25T09:38:21.897257Z'}},
#    'outputs': [],
#    'source': 'df = pd.read_html(\'https://fbref.com/en/comps/9/Premier-League-Stats\', attrs={"id": "results2024-202591_overall"})[0]',
#    'id': '9ba458d1'},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:21.902595',
#      'end_time': '2024-09-25T09:38:21.909271',
#      'duration': 0.006676,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:21.904640Z',
#      'iopub.execute_input': '2024-09-25T09:38:21.904640Z',
#      'iopub.status.idle': '2024-09-25T09:38:21.908096Z',
#      'shell.execute_reply': '2024-09-25T09:38:21.908096Z'}},
#    'outputs': [],
#    'source': "df = df.drop(columns=['Notes'])",
#    'id': '86b2db18'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:21.910275',
#      'end_time': '2024-09-25T09:38:21.918441',
#      'duration': 0.008166,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:21.911808Z',
#      'iopub.execute_input': '2024-09-25T09:38:21.912812Z',
#      'shell.execute_reply': '2024-09-25T09:38:21.917433Z',
#      'iopub.status.idle': '2024-09-25T09:38:21.917433Z'}},
#    'outputs': [],
#    'source': "df.to_csv('Current_Premier_League_Table.csv', index=False)",
#    'id': '69587a03'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:21.919945',
#      'end_time': '2024-09-25T09:38:21.939650',
#      'duration': 0.019705,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:21.921975Z',
#      'iopub.execute_input': '2024-09-25T09:38:21.922980Z',
#      'iopub.status.idle': '2024-09-25T09:38:21.938259Z',
#      'shell.execute_reply': '2024-09-25T09:38:21.938259Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '   Rk            Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP    xG  xGA  xGD  \\\n0   1  Manchester City   5  4  1  0  13   5   8   13     2.6  11.3  3.6  7.7   \n1   2        Liverpool   5  4  0  1  10   1   9   12     2.4   9.8  3.9  6.0   \n2   3      Aston Villa   5  4  0  1  10   7   3   12     2.4   8.4  5.0  3.4   \n3   4          Arsenal   5  3  2  0   8   3   5   11     2.2   5.6  6.3 -0.7   \n4   5          Chelsea   5  3  1  1  11   5   6   10     2.0   7.9  5.8  2.1   \n\n   xGD/90     Last 5  Attendance                     Top Team Scorer  \\\n0    1.55  W W W W D       52648                 Erling Haaland - 10   \n1    1.19  W W W L W       60181                       Luis Díaz - 5   \n2    0.68  W L W W W       41580                      Jhon Durán - 4   \n3   -0.13  W W D W D       60294  Kai Havertz, Gabriel Magalhães - 2   \n4    0.41  L W D W W       39558                 Nicolas Jackson - 4   \n\n          Goalkeeper  \n0            Ederson  \n1            Alisson  \n2  Emiliano Martínez  \n3         David Raya  \n4     Robert Sánchez  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Rk</th>\n      <th>Squad</th>\n      <th>MP</th>\n      <th>W</th>\n      <th>D</th>\n      <th>L</th>\n      <th>GF</th>\n      <th>GA</th>\n      <th>GD</th>\n      <th>Pts</th>\n      <th>Pts/MP</th>\n      <th>xG</th>\n      <th>xGA</th>\n      <th>xGD</th>\n      <th>xGD/90</th>\n      <th>Last 5</th>\n      <th>Attendance</th>\n      <th>Top Team Scorer</th>\n      <th>Goalkeeper</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>1</td>\n      <td>Manchester City</td>\n      <td>5</td>\n      <td>4</td>\n      <td>1</td>\n      <td>0</td>\n      <td>13</td>\n      <td>5</td>\n      <td>8</td>\n      <td>13</td>\n      <td>2.6</td>\n      <td>11.3</td>\n      <td>3.6</td>\n      <td>7.7</td>\n      <td>1.55</td>\n      <td>W W W W D</td>\n      <td>52648</td>\n      <td>Erling Haaland - 10</td>\n      <td>Ederson</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>2</td>\n      <td>Liverpool</td>\n      <td>5</td>\n      <td>4</td>\n      <td>0</td>\n      <td>1</td>\n      <td>10</td>\n      <td>1</td>\n      <td>9</td>\n      <td>12</td>\n      <td>2.4</td>\n      <td>9.8</td>\n      <td>3.9</td>\n      <td>6.0</td>\n      <td>1.19</td>\n      <td>W W W L W</td>\n      <td>60181</td>\n      <td>Luis Díaz - 5</td>\n      <td>Alisson</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>3</td>\n      <td>Aston Villa</td>\n      <td>5</td>\n      <td>4</td>\n      <td>0</td>\n      <td>1</td>\n      <td>10</td>\n      <td>7</td>\n      <td>3</td>\n      <td>12</td>\n      <td>2.4</td>\n      <td>8.4</td>\n      <td>5.0</td>\n      <td>3.4</td>\n      <td>0.68</td>\n      <td>W L W W W</td>\n      <td>41580</td>\n      <td>Jhon Durán - 4</td>\n      <td>Emiliano Martínez</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>4</td>\n      <td>Arsenal</td>\n      <td>5</td>\n      <td>3</td>\n      <td>2</td>\n      <td>0</td>\n      <td>8</td>\n      <td>3</td>\n      <td>5</td>\n      <td>11</td>\n      <td>2.2</td>\n      <td>5.6</td>\n      <td>6.3</td>\n      <td>-0.7</td>\n      <td>-0.13</td>\n      <td>W W D W D</td>\n      <td>60294</td>\n      <td>Kai Havertz, Gabriel Magalhães - 2</td>\n      <td>David Raya</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>5</td>\n      <td>Chelsea</td>\n      <td>5</td>\n      <td>3</td>\n      <td>1</td>\n      <td>1</td>\n      <td>11</td>\n      <td>5</td>\n      <td>6</td>\n      <td>10</td>\n      <td>2.0</td>\n      <td>7.9</td>\n      <td>5.8</td>\n      <td>2.1</td>\n      <td>0.41</td>\n      <td>L W D W W</td>\n      <td>39558</td>\n      <td>Nicolas Jackson - 4</td>\n      <td>Robert Sánchez</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 5}],
#    'source': 'df.head()',
#    'id': 'f85ccc2a'},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:21.941155',
#      'end_time': '2024-09-25T09:38:22.698507',
#      'duration': 0.757352,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:21.943156Z',
#      'iopub.execute_input': '2024-09-25T09:38:21.943156Z',
#      'iopub.status.idle': '2024-09-25T09:38:22.697500Z',
#      'shell.execute_reply': '2024-09-25T09:38:22.697500Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "CSV file has been written to the database as the table 'current_premier_league_table'.\n"}],
#    'source': 'import pandas as pd\nfrom sqlalchemy import create_engine, text\n\ncsv_file_path = r\'C:\\Users\\Sangharsh\\Desktop\\git\\Real-Time-Match-Result-Prediction\\Current_Premier_League_Table.csv\'\n\ndf = pd.read_csv(csv_file_path)\n\nengine = create_engine(\'mysql+mysqlconnector://root:hotspurs@localhost/premier_league\')\n\ntable_name = \'current_premier_league_table\'\n\nwith engine.connect() as connection:\n    connection.execute(text(f"DROP TABLE IF EXISTS {table_name}"))\n\ntry:\n    df.to_sql(table_name, con=engine, if_exists=\'replace\', index=False)\n    print(f"CSV file has been written to the database as the table \'{table_name}\'.")\nexcept Exception as e:\n    print(f"An error occurred: {e}")\n',
#    'id': '0e1fe07d'}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.5',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 2,
#   'papermill': {'default_parameters': {},
#    'parameters': {},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Sangharsh\\Desktop\\git\\Real-Time-Match-Result-Prediction\\Prem_Current_Table.ipynb',
#    'output_path': 'C:\\Users\\Sangharsh\\Desktop\\git\\Real-Time-Match-Result-Prediction\\output.ipynb',
#    'start_time': '2024-09-25T09:38:18.272649',
#    'end_time': '2024-09-25T09:38:23.062080',
#    'duration': 4.789431,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %%
import papermill as pm

notebook_input_path = r"C:\Users\Sangharsh\Desktop\git\Real-Time-Match-Result-Prediction\Squad_stats.ipynb"
notebook_output_path = r"C:\Users\Sangharsh\Desktop\git\Real-Time-Match-Result-Prediction\output.ipynb"

pm.execute_notebook(notebook_input_path, notebook_output_path)
# Out:
# Executing:   0%|          | 0/5 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:24.362809',
#      'end_time': '2024-09-25T09:38:24.756273',
#      'duration': 0.393464,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:24.365820Z',
#      'iopub.execute_input': '2024-09-25T09:38:24.366839Z',
#      'iopub.status.idle': '2024-09-25T09:38:24.755269Z',
#      'shell.execute_reply': '2024-09-25T09:38:24.755269Z'}},
#    'outputs': [],
#    'source': 'import pandas as pd',
#    'id': '836b7f5f'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:24.758290',
#      'end_time': '2024-09-25T09:38:25.479066',
#      'duration': 0.720776,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:24.760448Z',
#      'iopub.execute_input': '2024-09-25T09:38:24.760448Z',
#      'iopub.status.idle': '2024-09-25T09:38:25.477621Z',
#      'shell.execute_reply': '2024-09-25T09:38:25.477621Z'}},
#    'outputs': [],
#    'source': 'df = pd.read_html(\'https://fbref.com/en/comps/9/Premier-League-Stats\', attrs={"id": "stats_squads_standard_for"})[0]',
#    'id': 'a7da1863'},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:25.481073',
#      'end_time': '2024-09-25T09:38:25.487399',
#      'duration': 0.006326,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:25.483475Z',
#      'iopub.execute_input': '2024-09-25T09:38:25.483475Z',
#      'iopub.status.idle': '2024-09-25T09:38:25.486144Z',
#      'shell.execute_reply': '2024-09-25T09:38:25.486144Z'}},
#    'outputs': [],
#    'source': 'df.columns = df.columns.droplevel(0)',
#    'id': '675a0f48'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:25.488904',
#      'end_time': '2024-09-25T09:38:25.495598',
#      'duration': 0.006694,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:25.490006Z',
#      'iopub.execute_input': '2024-09-25T09:38:25.490006Z',
#      'iopub.status.idle': '2024-09-25T09:38:25.494593Z',
#      'shell.execute_reply': '2024-09-25T09:38:25.494593Z'}},
#    'outputs': [],
#    'source': "df.to_csv('Current_Squad_Stats.csv', index=False)",
#    'id': '8cac67aa'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:25.496598',
#      'end_time': '2024-09-25T09:38:25.734380',
#      'duration': 0.237782,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:25.499657Z',
#      'iopub.execute_input': '2024-09-25T09:38:25.500160Z',
#      'iopub.status.idle': '2024-09-25T09:38:25.733375Z',
#      'shell.execute_reply': '2024-09-25T09:38:25.733375Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "CSV file has been written to the database as the table 'current_squad_stats'.\n"}],
#    'source': 'import pandas as pd\nfrom sqlalchemy import create_engine, text\n\ncsv_file_path = r\'C:\\Users\\Sangharsh\\Desktop\\git\\Real-Time-Match-Result-Prediction\\Current_Squad_Stats.csv\'\n\ndf = pd.read_csv(csv_file_path)\n\nengine = create_engine(\'mysql+mysqlconnector://root:hotspurs@localhost/premier_league\')\n\ntable_name = \'current_squad_stats\'\n\nwith engine.connect() as connection:\n    connection.execute(text(f"DROP TABLE IF EXISTS {table_name}"))\n\ntry:\n    df.to_sql(table_name, con=engine, if_exists=\'replace\', index=False)\n    print(f"CSV file has been written to the database as the table \'{table_name}\'.")\nexcept Exception as e:\n    print(f"An error occurred: {e}")\n',
#    'id': '88da71ed'}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.5',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 2,
#   'papermill': {'default_parameters': {},
#    'parameters': {},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Sangharsh\\Desktop\\git\\Real-Time-Match-Result-Prediction\\Squad_stats.ipynb',
#    'output_path': 'C:\\Users\\Sangharsh\\Desktop\\git\\Real-Time-Match-Result-Prediction\\output.ipynb',
#    'start_time': '2024-09-25T09:38:23.084845',
#    'end_time': '2024-09-25T09:38:26.088650',
#    'duration': 3.003805,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %%
import papermill as pm

notebook_input_path = r"C:\Users\Sangharsh\Desktop\git\Real-Time-Match-Result-Prediction\fixtures_result.ipynb"
notebook_output_path = r"C:\Users\Sangharsh\Desktop\git\Real-Time-Match-Result-Prediction\output.ipynb"

pm.execute_notebook(notebook_input_path, notebook_output_path)
# Out:
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:27.410955',
#      'end_time': '2024-09-25T09:38:27.818511',
#      'duration': 0.407556,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:27.414585Z',
#      'iopub.execute_input': '2024-09-25T09:38:27.414585Z',
#      'iopub.status.idle': '2024-09-25T09:38:27.817501Z',
#      'shell.execute_reply': '2024-09-25T09:38:27.817501Z'}},
#    'outputs': [],
#    'source': 'import pandas as pd',
#    'id': 'c25438fa'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:27.820517',
#      'end_time': '2024-09-25T09:38:28.345157',
#      'duration': 0.52464,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:27.822359Z',
#      'iopub.execute_input': '2024-09-25T09:38:27.823512Z',
#      'shell.execute_reply': '2024-09-25T09:38:28.343155Z',
#      'iopub.status.idle': '2024-09-25T09:38:28.343155Z'}},
#    'outputs': [],
#    'source': 'df = pd.read_html(\'https://fbref.com/en/comps/9/schedule/Premier-League-Scores-and-Fixtures\', attrs={"id": "sched_2024-2025_9_1"})[0]',
#    'id': '9d104264'},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:28.347158',
#      'end_time': '2024-09-25T09:38:28.352811',
#      'duration': 0.005653,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:28.349311Z',
#      'iopub.execute_input': '2024-09-25T09:38:28.349311Z',
#      'shell.execute_reply': '2024-09-25T09:38:28.351810Z',
#      'iopub.status.idle': '2024-09-25T09:38:28.351810Z'}},
#    'outputs': [],
#    'source': "pd.set_option('display.max_columns', None)",
#    'id': '5f16b13c'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:28.353812',
#      'end_time': '2024-09-25T09:38:28.362040',
#      'duration': 0.008228,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:28.355812Z',
#      'iopub.execute_input': '2024-09-25T09:38:28.356812Z',
#      'iopub.status.idle': '2024-09-25T09:38:28.361038Z',
#      'shell.execute_reply': '2024-09-25T09:38:28.361038Z'}},
#    'outputs': [],
#    'source': "df = df.drop(columns=['Notes'])\ndf = df.drop(columns=['Referee'])\ndf = df.drop(columns=['Match Report'])\ndf = df.drop(columns=['Venue'])\ndf = df.drop(columns=['Attendance'])",
#    'id': '4ab45380'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:28.364040',
#      'end_time': '2024-09-25T09:38:28.368983',
#      'duration': 0.004943,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:28.365041Z',
#      'iopub.execute_input': '2024-09-25T09:38:28.366041Z',
#      'iopub.status.idle': '2024-09-25T09:38:28.367982Z',
#      'shell.execute_reply': '2024-09-25T09:38:28.367982Z'}},
#    'outputs': [],
#    'source': "pd.set_option('display.max_rows', None)",
#    'id': 'e1e94f83'},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:28.369984',
#      'end_time': '2024-09-25T09:38:28.376844',
#      'duration': 0.00686,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:28.371984Z',
#      'iopub.execute_input': '2024-09-25T09:38:28.372984Z',
#      'iopub.status.idle': '2024-09-25T09:38:28.375843Z',
#      'shell.execute_reply': '2024-09-25T09:38:28.375843Z'}},
#    'outputs': [],
#    'source': "df = df.dropna(subset=['Day'])",
#    'id': '3bda29dd'},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:28.377845',
#      'end_time': '2024-09-25T09:38:28.386353',
#      'duration': 0.008508,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:28.379845Z',
#      'iopub.execute_input': '2024-09-25T09:38:28.380845Z',
#      'iopub.status.idle': '2024-09-25T09:38:28.385347Z',
#      'shell.execute_reply': '2024-09-25T09:38:28.385347Z'}},
#    'outputs': [],
#    'source': "df.to_csv('Current_Fixtures_result.csv', index=False)",
#    'id': '599b5ae8'},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-09-25T09:38:28.387355',
#      'end_time': '2024-09-25T09:38:28.650021',
#      'duration': 0.262666,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-09-25T09:38:28.389504Z',
#      'iopub.execute_input': '2024-09-25T09:38:28.390734Z',
#      'iopub.status.idle': '2024-09-25T09:38:28.649015Z',
#      'shell.execute_reply': '2024-09-25T09:38:28.649015Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "CSV file has been written to the database as the table 'current_fixtures_result'.\n"}],
#    'source': 'import pandas as pd\nfrom sqlalchemy import create_engine, text\n\ncsv_file_path = r\'C:\\Users\\Sangharsh\\Desktop\\git\\Real-Time-Match-Result-Prediction\\Current_Fixtures_result.csv\'\n\ndf = pd.read_csv(csv_file_path)\n\nengine = create_engine(\'mysql+mysqlconnector://root:hotspurs@localhost/premier_league\')\n\ntable_name = \'current_fixtures_result\'\n\nwith engine.connect() as connection:\n    connection.execute(text(f"DROP TABLE IF EXISTS {table_name}"))\n\ntry:\n    df.to_sql(table_name, con=engine, if_exists=\'replace\', index=False)\n    print(f"CSV file has been written to the database as the table \'{table_name}\'.")\nexcept Exception as e:\n    print(f"An error occurred: {e}")\n',
#    'id': '0fb35865'}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.5',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'orig_nbformat_minor': 2,
#   'papermill': {'default_parameters': {},
#    'parameters': {},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'C:\\Users\\Sangharsh\\Desktop\\git\\Real-Time-Match-Result-Prediction\\fixtures_result.ipynb',
#    'output_path': 'C:\\Users\\Sangharsh\\Desktop\\git\\Real-Time-Match-Result-Prediction\\output.ipynb',
#    'start_time': '2024-09-25T09:38:26.116724',
#    'end_time': '2024-09-25T09:38:28.998783',
#    'duration': 2.882059,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}
