# %%
import pandas as pd

# %%
df = pd.read_html('https://fbref.com/en/comps/9/Premier-League-Stats', attrs={"id": "results2024-202591_overall"})[0]

# %%
df = df.drop(columns=['Notes'])

# %%
df.to_csv('Current_Premier_League_Table.csv', index=False)

# %%
df.head()
# Out:
#    Rk            Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP    xG  xGA  xGD  \
# 0   1  Manchester City   5  4  1  0  13   5   8   13     2.6  11.3  3.6  7.7
# 1   2        Liverpool   5  4  0  1  10   1   9   12     2.4   9.8  3.9  6.0
# 2   3      Aston Villa   5  4  0  1  10   7   3   12     2.4   8.4  5.0  3.4
# 3   4          Arsenal   5  3  2  0   8   3   5   11     2.2   5.6  6.3 -0.7
# 4   5          Chelsea   5  3  1  1  11   5   6   10     2.0   7.9  5.8  2.1
#
#    xGD/90     Last 5  Attendance                     Top Team Scorer  \
# 0    1.55  W W W W D       52648                 Erling Haaland - 10
# 1    1.19  W W W L W       60181                       Luis Díaz - 5
# 2    0.68  W L W W W       41580                      Jhon Durán - 4
# 3   -0.13  W W D W D       60294  Kai Havertz, Gabriel Magalhães - 2
# 4    0.41  L W D W W       39558                 Nicolas Jackson - 4
#
#           Goalkeeper
# 0            Ederson
# 1            Alisson
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine, text

csv_file_path = r'C:\Users\Sangharsh\Desktop\git\Real-Time-Match-Result-Prediction\Current_Premier_League_Table.csv'

df = pd.read_csv(csv_file_path)

engine = create_engine('mysql+mysqlconnector://root:hotspurs@localhost/premier_league')

table_name = 'current_premier_league_table'

with engine.connect() as connection:
    connection.execute(text(f"DROP TABLE IF EXISTS {table_name}"))

try:
    df.to_sql(table_name, con=engine, if_exists='replace', index=False)
    print(f"CSV file has been written to the database as the table '{table_name}'.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# CSV file has been written to the database as the table 'current_premier_league_table'.
